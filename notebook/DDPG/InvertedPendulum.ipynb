# %%
#import libs

import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from torch.distributions.normal import Normal
import torch.multiprocessing as mp

import gymnasium as gym

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
plt.rcParams["figure.figsize"] = (10, 5)
# Out:
# cuda

# %%
#Khởi tạo môi trường

env_name = "InvertedPendulum-v4"
# Create and wrap the environment
env = gym.make(env_name)
wrapped_env = gym.wrappers.RecordEpisodeStatistics(env, 50)  # Records episode-reward

# Observation-space of InvertedPendulum-v4 (4)
obs_space_dims = env.observation_space.shape[0]
# Action-space of InvertedPendulum-v4 (1)
action_space_dims = env.action_space.shape[0]
rewards_over_seeds = []

# %%
#Tạo folder kết quả

import os
def mkdir(path): 
    if not os.path.exists(path):
        os.mkdir(path)

save_path = "./save"
env_path = f'{save_path}/{env_name}'
model_path = f'{save_path}/{env_name}/model'
demo_path = f'{save_path}/{env_name}/demo'

mkdir(save_path)
mkdir(env_path)
mkdir(model_path)
mkdir(demo_path)

# %%
# Import necessary libraries
from stable_baselines3 import DDPG
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# Set the seed and other training parameters
seed_set = [1]
total_num_episodes = 100000  # Total number of episodes
evaluation_interval = 1000
learning_rate = 1e-3

# Initialize an empty list to store rewards over different seeds
rewards_over_seeds = []

for seed in seed_set:
    # Set the random seed for reproducibility
    np.random.seed(seed)
    torch.manual_seed(seed)

    # Initialize the SAC agent
    model = DDPG("MlpPolicy", env, verbose=0, seed=seed, learning_rate=learning_rate)

    rewards = []

    for episode in range(0, total_num_episodes + 1, evaluation_interval):
        if episode > 0:
            # Continue training the agent
            model.learn(total_timesteps=evaluation_interval)

        # Evaluate the agent
        mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
        print(f"Seed: {seed}, Episode: {episode}, Mean Reward: {mean_reward}, Std Reward: {std_reward}")
        rewards.append((episode, mean_reward))

        # Save the model
        model.save(f"{model_path}/{env_name}_ddpg_seed_{seed}_episode_{episode}")

    rewards_over_seeds.append(rewards)

# Output the rewards for different seeds
print(rewards_over_seeds)
# Out:
# /home/admin/miniconda3/envs/tue.cm210908/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Seed: 1, Episode: 0, Mean Reward: 11.8, Std Reward: 0.7483314773547883
# Seed: 1, Episode: 1000, Mean Reward: 85.4, Std Reward: 13.03993865016243
# Seed: 1, Episode: 2000, Mean Reward: 55.7, Std Reward: 1.4866068747318506
# Seed: 1, Episode: 3000, Mean Reward: 113.3, Std Reward: 39.117898716572185
# Seed: 1, Episode: 4000, Mean Reward: 45.0, Std Reward: 0.6324555320336759
# Seed: 1, Episode: 5000, Mean Reward: 65.7, Std Reward: 1.4177446878757824
# Seed: 1, Episode: 6000, Mean Reward: 58.0, Std Reward: 1.2649110640673518
# Seed: 1, Episode: 7000, Mean Reward: 49.0, Std Reward: 0.6324555320336759
# Seed: 1, Episode: 8000, Mean Reward: 50.6, Std Reward: 0.66332495807108
# Seed: 1, Episode: 9000, Mean Reward: 65.9, Std Reward: 2.5079872407968904
# Seed: 1, Episode: 10000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 11000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 12000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 13000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 14000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 15000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 16000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 17000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 18000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 19000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 20000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 21000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 22000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 23000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 24000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 25000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 26000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 27000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 28000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 29000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 30000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 31000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 32000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 33000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 34000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 35000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 36000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 37000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 38000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 39000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 40000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 41000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 42000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 43000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 44000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 45000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 46000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 47000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 48000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 49000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 50000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 51000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 52000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 53000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 54000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 55000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 56000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 57000, Mean Reward: 109.1, Std Reward: 50.62894429079082
# Seed: 1, Episode: 58000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 59000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 60000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 61000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 62000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 63000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 64000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 65000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 66000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 67000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 68000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 69000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 70000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 71000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 72000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 73000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 74000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 75000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 76000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 77000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 78000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 79000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 80000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 81000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 82000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 83000, Mean Reward: 489.2, Std Reward: 342.5188461968188
# Seed: 1, Episode: 84000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 85000, Mean Reward: 824.1, Std Reward: 351.80859853050777
# Seed: 1, Episode: 86000, Mean Reward: 407.5, Std Reward: 483.77437923064923
# Seed: 1, Episode: 87000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 88000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 89000, Mean Reward: 120.1, Std Reward: 2.071231517720798
# Seed: 1, Episode: 90000, Mean Reward: 68.0, Std Reward: 26.814175355583846
# Seed: 1, Episode: 91000, Mean Reward: 52.3, Std Reward: 0.45825756949558394
# Seed: 1, Episode: 92000, Mean Reward: 106.0, Std Reward: 76.14197265634769
# Seed: 1, Episode: 93000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 94000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 95000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 96000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 97000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 98000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 99000, Mean Reward: 1000.0, Std Reward: 0.0
# Seed: 1, Episode: 100000, Mean Reward: 1000.0, Std Reward: 0.0
# [[(0, 11.8), (1000, 85.4), (2000, 55.7), (3000, 113.3), (4000, 45.0), (5000, 65.7), (6000, 58.0), (7000, 49.0), (8000, 50.6), (9000, 65.9), (10000, 1000.0), (11000, 1000.0), (12000, 1000.0), (13000, 1000.0), (14000, 1000.0), (15000, 1000.0), (16000, 1000.0), (17000, 1000.0), (18000, 1000.0), (19000, 1000.0), (20000, 1000.0), (21000, 1000.0), (22000, 1000.0), (23000, 1000.0), (24000, 1000.0), (25000, 1000.0), (26000, 1000.0), (27000, 1000.0), (28000, 1000.0), (29000, 1000.0), (30000, 1000.0), (31000, 1000.0), (32000, 1000.0), (33000, 1000.0), (34000, 1000.0), (35000, 1000.0), (36000, 1000.0), (37000, 1000.0), (38000, 1000.0), (39000, 1000.0), (40000, 1000.0), (41000, 1000.0), (42000, 1000.0), (43000, 1000.0), (44000, 1000.0), (45000, 1000.0), (46000, 1000.0), (47000, 1000.0), (48000, 1000.0), (49000, 1000.0), (50000, 1000.0), (51000, 1000.0), (52000, 1000.0), (53000, 1000.0), (54000, 1000.0), (55000, 1000.0), (56000, 1000.0), (57000, 109.1), (58000, 1000.0), (59000, 1000.0), (60000, 1000.0), (61000, 1000.0), (62000, 1000.0), (63000, 1000.0), (64000, 1000.0), (65000, 1000.0), (66000, 1000.0), (67000, 1000.0), (68000, 1000.0), (69000, 1000.0), (70000, 1000.0), (71000, 1000.0), (72000, 1000.0), (73000, 1000.0), (74000, 1000.0), (75000, 1000.0), (76000, 1000.0), (77000, 1000.0), (78000, 1000.0), (79000, 1000.0), (80000, 1000.0), (81000, 1000.0), (82000, 1000.0), (83000, 489.2), (84000, 1000.0), (85000, 824.1), (86000, 407.5), (87000, 1000.0), (88000, 1000.0), (89000, 120.1), (90000, 68.0), (91000, 52.3), (92000, 106.0), (93000, 1000.0), (94000, 1000.0), (95000, 1000.0), (96000, 1000.0), (97000, 1000.0), (98000, 1000.0), (99000, 1000.0), (100000, 1000.0)]]

# %%
# ploting
rewards_to_plot = []
for seed_index, seed_rewards in enumerate(rewards_over_seeds):
    for episode, reward in seed_rewards:
        rewards_to_plot.append([seed_set[seed_index], episode, reward])
 
df1 = pd.DataFrame(rewards_to_plot, columns=["seed", "episodes", "reward"])
 
# Visualize the rewards
sns.set(style="darkgrid", context="talk", palette="rainbow")
sns.lineplot(x="episodes", y="reward", hue="seed", data=df1).set(
    title="DDPG for InvertedPendulum-v4"
)
plt.show()
