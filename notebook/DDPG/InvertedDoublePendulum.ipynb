# %%
#import libs

import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from torch.distributions.normal import Normal
import torch.multiprocessing as mp

import gymnasium as gym

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
plt.rcParams["figure.figsize"] = (10, 5)
# Out:
# cuda

# %%
#Khởi tạo môi trường

env_name = "InvertedDoublePendulum-v4"
# Create and wrap the environment
env = gym.make(env_name)
wrapped_env = gym.wrappers.RecordEpisodeStatistics(env, 50)  # Records episode-reward

# Observation-space of InvertedPendulum-v4 (4)
obs_space_dims = env.observation_space.shape[0]
# Action-space of InvertedPendulum-v4 (1)
action_space_dims = env.action_space.shape[0]
rewards_over_seeds = []

# %%
#Tạo folder kết quả

import os
def mkdir(path): 
    if not os.path.exists(path):
        os.mkdir(path)

save_path = "./save"
env_path = f'{save_path}/{env_name}'
model_path = f'{save_path}/{env_name}/model'
demo_path = f'{save_path}/{env_name}/demo'

mkdir(save_path)
mkdir(env_path)
mkdir(model_path)
mkdir(demo_path)

# %%
# Import necessary libraries
from stable_baselines3 import DDPG
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# Set the seed and other training parameters
seed_set = [1]
total_num_episodes = 100000  # Total number of episodes
evaluation_interval = 1000
learning_rate = 1e-4

# Initialize an empty list to store rewards over different seeds
rewards_over_seeds = []

for seed in seed_set:
    # Set the random seed for reproducibility
    np.random.seed(seed)
    torch.manual_seed(seed)

    # Initialize the SAC agent
    model = DDPG("MlpPolicy", env, verbose=0, seed=seed, learning_rate=learning_rate)

    rewards = []

    for episode in range(0, total_num_episodes + 1, evaluation_interval):
        if episode > 0:
            # Continue training the agent
            model.learn(total_timesteps=evaluation_interval)

        # Evaluate the agent
        mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
        print(f"Seed: {seed}, Episode: {episode}, Mean Reward: {mean_reward}, Std Reward: {std_reward}")
        rewards.append((episode, mean_reward))

        # Save the model
        model.save(f"{model_path}/{env_name}_ddpg_seed_{seed}_episode_{episode}")

    rewards_over_seeds.append(rewards)

# Output the rewards for different seeds
print(rewards_over_seeds)
# Out:
# /home/admin/miniconda3/envs/tue.cm210908/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Seed: 1, Episode: 0, Mean Reward: 90.14946250915527, Std Reward: 18.728903788247745
# Seed: 1, Episode: 1000, Mean Reward: 30.20578908920288, Std Reward: 4.068630914472936
# Seed: 1, Episode: 2000, Mean Reward: 108.74717950820923, Std Reward: 16.041582344426057
# Seed: 1, Episode: 3000, Mean Reward: 121.4389476776123, Std Reward: 18.947902013235865
# Seed: 1, Episode: 4000, Mean Reward: 145.34738302230835, Std Reward: 30.451034956913443
# Seed: 1, Episode: 5000, Mean Reward: 178.6448739051819, Std Reward: 38.85565391168148
# Seed: 1, Episode: 6000, Mean Reward: 236.5543074607849, Std Reward: 45.17314985824257
# Seed: 1, Episode: 7000, Mean Reward: 283.6462112426758, Std Reward: 56.43789678749898
# Seed: 1, Episode: 8000, Mean Reward: 306.4432997703552, Std Reward: 107.75929115774194
# Seed: 1, Episode: 9000, Mean Reward: 371.0246612548828, Std Reward: 115.96113512287744
# Seed: 1, Episode: 10000, Mean Reward: 318.0778414726257, Std Reward: 100.89397408049092
# Seed: 1, Episode: 11000, Mean Reward: 340.67838325500486, Std Reward: 91.97226754575203
# Seed: 1, Episode: 12000, Mean Reward: 319.19326601028445, Std Reward: 64.32737584483154
# Seed: 1, Episode: 13000, Mean Reward: 318.4640827178955, Std Reward: 62.99242826030356
# Seed: 1, Episode: 14000, Mean Reward: 333.64758224487304, Std Reward: 131.97454171911465
# Seed: 1, Episode: 15000, Mean Reward: 368.19313259124755, Std Reward: 138.07728695962925
# Seed: 1, Episode: 16000, Mean Reward: 422.68393459320066, Std Reward: 147.59168458090753
# Seed: 1, Episode: 17000, Mean Reward: 412.30986642837524, Std Reward: 121.9620286897803
# Seed: 1, Episode: 18000, Mean Reward: 558.5381128311158, Std Reward: 251.87436901805935
# Seed: 1, Episode: 19000, Mean Reward: 530.5410056114197, Std Reward: 239.24457293582694
# Seed: 1, Episode: 20000, Mean Reward: 429.33622179031374, Std Reward: 162.40808505123093
# Seed: 1, Episode: 21000, Mean Reward: 630.6044410705566, Std Reward: 381.32154880497154
# Seed: 1, Episode: 22000, Mean Reward: 519.9681386947632, Std Reward: 219.52435737031854
# Seed: 1, Episode: 23000, Mean Reward: 733.4614351272583, Std Reward: 371.8800181958135
# Seed: 1, Episode: 24000, Mean Reward: 882.3577260971069, Std Reward: 650.0226145958346
# Seed: 1, Episode: 25000, Mean Reward: 4164.585633277893, Std Reward: 4244.523878924414
# Seed: 1, Episode: 26000, Mean Reward: 9359.249444675446, Std Reward: 0.22499367724112648
# Seed: 1, Episode: 27000, Mean Reward: 9359.337988948822, Std Reward: 0.11180688600643836
# Seed: 1, Episode: 28000, Mean Reward: 8483.247929477691, Std Reward: 2628.8388592736237
# Seed: 1, Episode: 29000, Mean Reward: 8468.871210384368, Std Reward: 2670.784864428595
# Seed: 1, Episode: 30000, Mean Reward: 8462.599868869782, Std Reward: 2687.5055099973697
# Seed: 1, Episode: 31000, Mean Reward: 9358.514008903503, Std Reward: 0.07219843945212281
# Seed: 1, Episode: 32000, Mean Reward: 9358.222797107697, Std Reward: 0.06463622487279386
# Seed: 1, Episode: 33000, Mean Reward: 9357.90453529358, Std Reward: 0.058949324882124635
# Seed: 1, Episode: 34000, Mean Reward: 9358.576931095124, Std Reward: 0.09706280879289063
# Seed: 1, Episode: 35000, Mean Reward: 9359.565551567077, Std Reward: 0.3308463019068278
# Seed: 1, Episode: 36000, Mean Reward: 9357.978049850464, Std Reward: 0.1339676890204284
# Seed: 1, Episode: 37000, Mean Reward: 1818.1910413742066, Std Reward: 120.50602857256987
# Seed: 1, Episode: 38000, Mean Reward: 9359.44220981598, Std Reward: 0.22112890298444152
# Seed: 1, Episode: 39000, Mean Reward: 9358.873777580262, Std Reward: 0.24736373556572128
# Seed: 1, Episode: 40000, Mean Reward: 9359.526221561431, Std Reward: 0.1435646014457323
# Seed: 1, Episode: 41000, Mean Reward: 2095.0545186042787, Std Reward: 226.53063726350757
# Seed: 1, Episode: 42000, Mean Reward: 1433.4985034942626, Std Reward: 225.1514363783171
# Seed: 1, Episode: 43000, Mean Reward: 9359.65853805542, Std Reward: 0.06575590260608885
# Seed: 1, Episode: 44000, Mean Reward: 8559.844699287414, Std Reward: 2398.5884071763635
# Seed: 1, Episode: 45000, Mean Reward: 5661.907244300843, Std Reward: 3722.6164484036613
# Seed: 1, Episode: 46000, Mean Reward: 6924.297452926636, Std Reward: 3719.530967847381
# Seed: 1, Episode: 47000, Mean Reward: 5336.264725112915, Std Reward: 4025.6179674130726
# Seed: 1, Episode: 48000, Mean Reward: 9358.60145483017, Std Reward: 0.21015638590391683
# Seed: 1, Episode: 49000, Mean Reward: 9358.182347488404, Std Reward: 0.1495377450697944
# Seed: 1, Episode: 50000, Mean Reward: 9358.404069519043, Std Reward: 0.1374504920774488
# Seed: 1, Episode: 51000, Mean Reward: 9358.383464241027, Std Reward: 0.12049137426627382
# Seed: 1, Episode: 52000, Mean Reward: 9358.648273563385, Std Reward: 0.2817454146313948
# Seed: 1, Episode: 53000, Mean Reward: 9358.049251651764, Std Reward: 0.2810624813759689
# Seed: 1, Episode: 54000, Mean Reward: 9358.806618118286, Std Reward: 0.13664260262093278
# Seed: 1, Episode: 55000, Mean Reward: 9357.557819271087, Std Reward: 0.23094263795477268
# Seed: 1, Episode: 56000, Mean Reward: 9357.082609272004, Std Reward: 0.25006438825381844
# Seed: 1, Episode: 57000, Mean Reward: 9356.934941005708, Std Reward: 0.07619037691470479
# Seed: 1, Episode: 58000, Mean Reward: 9355.873971176148, Std Reward: 1.7540687068501888
# Seed: 1, Episode: 59000, Mean Reward: 9356.1016828537, Std Reward: 2.6075007944083723
# Seed: 1, Episode: 60000, Mean Reward: 9356.226856327057, Std Reward: 0.27849981353624975
# Seed: 1, Episode: 61000, Mean Reward: 9356.258005046844, Std Reward: 0.15449259014121935
# Seed: 1, Episode: 62000, Mean Reward: 9356.97935848236, Std Reward: 0.21571459368533688
# Seed: 1, Episode: 63000, Mean Reward: 9356.820538330077, Std Reward: 0.33097090837278037
# Seed: 1, Episode: 64000, Mean Reward: 9356.274157524109, Std Reward: 0.18608600105295664
# Seed: 1, Episode: 65000, Mean Reward: 9354.738406276703, Std Reward: 0.8111921345699068
# Seed: 1, Episode: 66000, Mean Reward: 9356.046802902221, Std Reward: 0.1216219050394778
# Seed: 1, Episode: 67000, Mean Reward: 9354.079439163208, Std Reward: 0.6409133508847957
# Seed: 1, Episode: 68000, Mean Reward: 9356.237611103057, Std Reward: 0.1081270571527715
# Seed: 1, Episode: 69000, Mean Reward: 9355.456338596345, Std Reward: 1.041468931884709
# Seed: 1, Episode: 70000, Mean Reward: 9356.635603237151, Std Reward: 0.13248864253987125
# Seed: 1, Episode: 71000, Mean Reward: 9355.892616558074, Std Reward: 0.6527417523008161
# Seed: 1, Episode: 72000, Mean Reward: 8443.863473796844, Std Reward: 2737.842808653725
# Seed: 1, Episode: 73000, Mean Reward: 9354.031737995148, Std Reward: 1.3209915734242792
# Seed: 1, Episode: 74000, Mean Reward: 9354.942022800446, Std Reward: 0.7284089589058192
# Seed: 1, Episode: 75000, Mean Reward: 9353.801242351532, Std Reward: 0.21540863329129833
# Seed: 1, Episode: 76000, Mean Reward: 9350.568210983276, Std Reward: 0.09924468741887818
# Seed: 1, Episode: 77000, Mean Reward: 9351.87817258835, Std Reward: 0.12622671555138107
# Seed: 1, Episode: 78000, Mean Reward: 9348.054053497315, Std Reward: 0.46199712090221906
# Seed: 1, Episode: 79000, Mean Reward: 9354.719679927826, Std Reward: 0.1753318370623621
# Seed: 1, Episode: 80000, Mean Reward: 9351.580179023742, Std Reward: 0.35054229846583257
# Seed: 1, Episode: 81000, Mean Reward: 9354.110943412781, Std Reward: 0.11298054252026123
# Seed: 1, Episode: 82000, Mean Reward: 9349.95499868393, Std Reward: 0.6963680023080667
# Seed: 1, Episode: 83000, Mean Reward: 9354.685415267944, Std Reward: 0.10600162034470122
# Seed: 1, Episode: 84000, Mean Reward: 9356.308113193512, Std Reward: 0.3215450418045076
# Seed: 1, Episode: 85000, Mean Reward: 9349.37611246109, Std Reward: 1.029520637790099
# Seed: 1, Episode: 86000, Mean Reward: 9349.127886867524, Std Reward: 3.745673438273587
# Seed: 1, Episode: 87000, Mean Reward: 9354.696319198609, Std Reward: 0.823464808171531
# Seed: 1, Episode: 88000, Mean Reward: 8444.78141231537, Std Reward: 2728.4299386077564
# Seed: 1, Episode: 89000, Mean Reward: 9350.800814533233, Std Reward: 2.729526295988594
# Seed: 1, Episode: 90000, Mean Reward: 8437.765230560302, Std Reward: 2738.7780968229863
# Seed: 1, Episode: 91000, Mean Reward: 9353.372437763213, Std Reward: 3.998970374680609
# Seed: 1, Episode: 92000, Mean Reward: 9354.310014724731, Std Reward: 0.9816196479271735
# Seed: 1, Episode: 93000, Mean Reward: 9341.476142787933, Std Reward: 0.4976328264280686
# Seed: 1, Episode: 94000, Mean Reward: 9346.034962368012, Std Reward: 1.1721428631096849
# Seed: 1, Episode: 95000, Mean Reward: 9341.329444599152, Std Reward: 1.5969785307022635
# Seed: 1, Episode: 96000, Mean Reward: 9346.677624225616, Std Reward: 0.3746823715772727
# Seed: 1, Episode: 97000, Mean Reward: 9343.864207267761, Std Reward: 0.35231803124456024
# Seed: 1, Episode: 98000, Mean Reward: 9339.892705249786, Std Reward: 1.892081981105775
# Seed: 1, Episode: 99000, Mean Reward: 9344.697556495667, Std Reward: 4.3604736092517
# Seed: 1, Episode: 100000, Mean Reward: 9345.675124931335, Std Reward: 3.2556957997469786
# [[(0, 90.14946250915527), (1000, 30.20578908920288), (2000, 108.74717950820923), (3000, 121.4389476776123), (4000, 145.34738302230835), (5000, 178.6448739051819), (6000, 236.5543074607849), (7000, 283.6462112426758), (8000, 306.4432997703552), (9000, 371.0246612548828), (10000, 318.0778414726257), (11000, 340.67838325500486), (12000, 319.19326601028445), (13000, 318.4640827178955), (14000, 333.64758224487304), (15000, 368.19313259124755), (16000, 422.68393459320066), (17000, 412.30986642837524), (18000, 558.5381128311158), (19000, 530.5410056114197), (20000, 429.33622179031374), (21000, 630.6044410705566), (22000, 519.9681386947632), (23000, 733.4614351272583), (24000, 882.3577260971069), (25000, 4164.585633277893), (26000, 9359.249444675446), (27000, 9359.337988948822), (28000, 8483.247929477691), (29000, 8468.871210384368), (30000, 8462.599868869782), (31000, 9358.514008903503), (32000, 9358.222797107697), (33000, 9357.90453529358), (34000, 9358.576931095124), (35000, 9359.565551567077), (36000, 9357.978049850464), (37000, 1818.1910413742066), (38000, 9359.44220981598), (39000, 9358.873777580262), (40000, 9359.526221561431), (41000, 2095.0545186042787), (42000, 1433.4985034942626), (43000, 9359.65853805542), (44000, 8559.844699287414), (45000, 5661.907244300843), (46000, 6924.297452926636), (47000, 5336.264725112915), (48000, 9358.60145483017), (49000, 9358.182347488404), (50000, 9358.404069519043), (51000, 9358.383464241027), (52000, 9358.648273563385), (53000, 9358.049251651764), (54000, 9358.806618118286), (55000, 9357.557819271087), (56000, 9357.082609272004), (57000, 9356.934941005708), (58000, 9355.873971176148), (59000, 9356.1016828537), (60000, 9356.226856327057), (61000, 9356.258005046844), (62000, 9356.97935848236), (63000, 9356.820538330077), (64000, 9356.274157524109), (65000, 9354.738406276703), (66000, 9356.046802902221), (67000, 9354.079439163208), (68000, 9356.237611103057), (69000, 9355.456338596345), (70000, 9356.635603237151), (71000, 9355.892616558074), (72000, 8443.863473796844), (73000, 9354.031737995148), (74000, 9354.942022800446), (75000, 9353.801242351532), (76000, 9350.568210983276), (77000, 9351.87817258835), (78000, 9348.054053497315), (79000, 9354.719679927826), (80000, 9351.580179023742), (81000, 9354.110943412781), (82000, 9349.95499868393), (83000, 9354.685415267944), (84000, 9356.308113193512), (85000, 9349.37611246109), (86000, 9349.127886867524), (87000, 9354.696319198609), (88000, 8444.78141231537), (89000, 9350.800814533233), (90000, 8437.765230560302), (91000, 9353.372437763213), (92000, 9354.310014724731), (93000, 9341.476142787933), (94000, 9346.034962368012), (95000, 9341.329444599152), (96000, 9346.677624225616), (97000, 9343.864207267761), (98000, 9339.892705249786), (99000, 9344.697556495667), (100000, 9345.675124931335)]]

# %%
# ploting
rewards_to_plot = []
for seed_index, seed_rewards in enumerate(rewards_over_seeds):
    for episode, reward in seed_rewards:
        rewards_to_plot.append([seed_set[seed_index], episode, reward])
 
df1 = pd.DataFrame(rewards_to_plot, columns=["seed", "episodes", "reward"])
 
# Visualize the rewards
sns.set(style="darkgrid", context="talk", palette="rainbow")
sns.lineplot(x="episodes", y="reward", hue="seed", data=df1).set(
    title="DDPG for InvertedDoublePendulum-v4"
)
plt.show()
